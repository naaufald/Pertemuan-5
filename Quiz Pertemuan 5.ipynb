# %% [markdown]
# # Data yang digunakan adalah harga laptop

# %% [markdown]
# #### data mencakup nama perusahaan, nama produk, type, screen size, screen resolution, CPU, CPU Type, CPU Frequency, RAM, SSD, GPU Company, GPU Type, berat, dan harga. data diambil dari kaggle.com

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataa = pd.read_csv(r'D:\Matana\Semester 3\eksplorasi dan visualisasi data\laptop_price.csv')
dataa
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
print(dataa.dtypes)
# Out:
# Company                 object
# Product                 object
# TypeName                object
# Inches                 float64
# ScreenResolution        object
# CPU_Company             object
# CPU_Type                object
# CPU_Frequency (GHz)    float64
# RAM (GB)                 int64
# Memory                  object
# GPU_Company             object
# GPU_Type                object
# OpSys                   object
# Weight (kg)            float64
# Price (Euro)           float64
# dtype: object

# %% [markdown]
# #### karena data yang diinginkan hanya yang berupa angka, maka kita akan memfilter data yang bukan angka.

# %%
selected_data = dataa[['Inches', 'CPU_Frequency (GHz)', 'RAM (GB)', 'Weight (kg)', 'Price (Euro)']]
print(selected_data)
# Out:
#       Inches  CPU_Frequency (GHz)  RAM (GB)  Weight (kg)  Price (Euro)
# 0       13.3                  2.3         8         1.37       1339.69
# 1       13.3                  1.8         8         1.34        898.94
# 2       15.6                  2.5         8         1.86        575.00
# 3       15.4                  2.7        16         1.83       2537.45
# 4       13.3                  3.1         8         1.37       1803.60
# ...      ...                  ...       ...          ...           ...
# 1270    14.0                  2.5         4         1.80        638.00
# 1271    13.3                  2.5        16         1.30       1499.00
# 1272    14.0                  1.6         2         1.50        229.00
# 1273    15.6                  2.5         6         2.19        764.00
# 1274    15.6                  1.6         4         2.20        369.00
#
# [1275 rows x 5 columns]

# %%
cov_matrix = selected_data.cov()
print(cov_matrix)
# Out:
#                         Inches  CPU_Frequency (GHz)     RAM (GB)  Weight (kg)  \
# Inches                2.043384             0.219698     1.756773     0.790758
# CPU_Frequency (GHz)   0.219698             0.253860     0.940726     0.107439
# RAM (GB)              1.756773             0.940726    25.987660     1.328311
# Weight (kg)           0.790758             0.107439     1.328311     0.447823
# Price (Euro)         66.721479           151.413584  2644.527542    99.360783
#
#                       Price (Euro)
# Inches                   66.721479
# CPU_Frequency (GHz)     151.413584
# RAM (GB)               2644.527542
# Weight (kg)              99.360783
# Price (Euro)         491054.072107

# %%
corre_matrix = selected_data.corr()
print(corre_matrix)
# Out:
#                        Inches  CPU_Frequency (GHz)  RAM (GB)  Weight (kg)  \
# Inches               1.000000             0.305037  0.241078     0.826638
# CPU_Frequency (GHz)  0.305037             1.000000  0.366254     0.318649
# RAM (GB)             0.241078             0.366254  1.000000     0.389370
# Weight (kg)          0.826638             0.318649  0.389370     1.000000
# Price (Euro)         0.066608             0.428847  0.740287     0.211883
#
#                      Price (Euro)
# Inches                   0.066608
# CPU_Frequency (GHz)      0.428847
# RAM (GB)                 0.740287
# Weight (kg)              0.211883
# Price (Euro)             1.000000

# %%
sns.heatmap(corre_matrix, annot=True, cmap='coolwarm')
plt.title('Heatmap Matriks Korelasi')
plt.show()

# %%
sns.heatmap(corre_matrix, annot=True, cmap='Blues')
plt.title('Heatmap Matriks Korelasi')
plt.show()

# %% [markdown]
# #### semakin gelap warna yang dihasilkan, berarti semakin tinggi korelasi antar variabel tersebut.

# %%
sns.pairplot(selected_data)
plt.title('Pair Plot Data')
plt.show()
